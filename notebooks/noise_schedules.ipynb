# %%
# Autoreload
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../")

import jax.numpy as np
import jax
import matplotlib.pyplot as plt

from models.diffusion_utils import NoiseScheduleFixedLinear, NoiseScheduleNet, NoiseScheduleScalar

# %%
model = NoiseScheduleNet(gamma_min=-9, gamma_max=6, n_features=32, nonlinear=True)

t = np.linspace(0., 1., 10)
gamma, params = model.init_with_output(jax.random.PRNGKey(0), t)

plt.plot(t, gamma)

# %%
model = NoiseScheduleFixedLinear(gamma_min=-6, gamma_max=6)

t = np.linspace(0., 1., 100)
gamma, params = model.init_with_output(jax.random.PRNGKey(0), t)

plt.plot(t, gamma)

# %%
model = NoiseScheduleScalar(gamma_min=-6, gamma_max=6)

t = np.linspace(0., 1., 100)
gamma, params = model.init_with_output(jax.random.PRNGKey(0), t)

plt.plot(t, gamma)
